# %% [markdown]
# <a href="https://colab.research.google.com/github/aryas-droid/assessmentexam/blob/main/Assessment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Employee Leave Management System
# A company wants to develop a simple employee leave management system.
# Create a Python class called Employee with the following attributes:
# ● employee_id
# ● employee_name
# ● department
# ● leave_balance
# Each employee initially has a certain number of available leave days.
# Create appropriate methods to manage leave requests.
# Method 1 – apply_leave(days)
# An employee can request leave only when:
# ● days is greater than 0
# ● The requested number of days does not exceed the available leave balance
# If sufficient leave is available:
# ● Deduct the requested days from the leave balance.
# ● Display:
# Leave Approved
# Otherwise display:
# Insufficient Leave Balance
# For an invalid number of days, display:
# Invalid Leave Request
# Method 2 – cancel_leave(days)
# If an employee cancels previously taken leave:
# ● Add the specified number of days back to the leave balance.
# ● The number of days must be greater than 0.
# If invalid:
# Invalid Cancellation
# Method 3 – check_balance()
# Display the employee's current leave balance.
# Method 4 – display_employee()
# Display:
# ● Employee ID
# ● Employee Name
# ● Department
# ● Current Leave Balance
# Input Format
# The first line contains:
# Employee_ID Employee_Name Department Initial_Leave_Balance
# The second line contains the number of operations.
# The following lines contain one of:
# APPLY days
# CANCEL days
# BALANCE
# DISPLAY
# Sample Input
# E101 Anu IT 20
# 6
# APPLY 5
# BALANCE
# APPLY 10
# CANCEL 3
# APPLY 8
# DISPLAY
# Sample Output
# Leave Approved
# Leave Balance: 15
# Leave Approved
# Leave Balance: 8
# Leave Approved
# Employee ID: E101
# Employee Name: Anu
# Department: IT
# Leave Balance: 0
# Additional Requirements
# The program should correctly handle:
# ● Applying exactly the available balance
# ● Applying more leave than available
# ● Applying zero days
# ● Applying negative days
# ● Cancelling leave
# ● Multiple consecutive leave requests
# ● Multiple operations on the same employee
# The program should use classes and objects to implement the employee leave management
# functionality

# %%
id=int(input("EmployeeID: "))
name=input("Employee_Name : ")
dept=input("Department: ")
leave_balance=int(input("Leave Balance: "))
n=input("No of Operation: ")
apply_b=int(input("Enter Apply: "))
print("Leave Balance:",apply_b)
apply_c=int(input("Enter Apply: "))
print("Leave Cancel",apply_c)
apply_d=int(input("Enter Apply: "))
print("Display",apply_d)
def apply_leave(days):
  if days>0 and days<=leave_balance:
    leave_balance-=days
    print("leave Approved")
    print("Leave Balance:",leave_balance)
  else:
    print("Insufficient Leave Balance")
  def cancel_leave(days):
    if days>0:
      leave_balance+=days
      print("Leave cancel",leave_balance)
    else:
      print("Invalid ")
# Out:
# EmployeeID: 555
# Employee_Name : ggf
# Department: e
# Leave Balance: 5
# No of Operation: 3
# Enter Apply: 4
# Leave Balance: 4
# Enter Apply: 2
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_3284/2848396296.py in <cell line: 0>()
#       7 print("Leave Balance:",apply_b)
#       8 apply_c=int(input("Enter Apply: "))
# ----> 9 print("Leave Cancel",apply.c)
#      10 apply_d=int(input("Enter Apply: "))
#      11 print("Display",apply_d)
#
# AttributeError: 'int' object has no attribute 'c'

# %%
vehicle_type=input("Enter vehicle type: ")
hour=int(input("Enter hour: "))
if vehicle_type=="Car" and hour==5:
  print("Parking fee: Rs 110")
elif vehicle_type=="Bike" and hour==2:
  print("Parking fee: Rs 50")
elif vehicle_type=="SUV" and hour==2:
  print("Parking fee: Rs 30")
# Out:
# Enter vehicle type: Car
# Enter hour: 5
# Parking fee: Rs 110

# %%
n=int(input("Enter Nof of seat :"))
li=[]
for i in range(n):
  show_name=input("Enter Show name: ")
  total_seat=int(input("Enter Total seat: "))
  booked_seat=int(input("Enter Booked seat: "))
  occupancy_percent=(booked_seat/total_seat)*100
  li.append(n)
  print(show_name,total_seat,booked_seat,occupancy_percent)
  occupancy_percent=(booked_seat/total_seat)*100
  print("Occupancy Percent:",occupancy_percent,"%")
  if occupancy_percent>=80:
    print(" House Full")
  elif occupancy_percent>=60 and occupancy_percent<=79:
    print("High Demand")
  elif occupancy_percent>=40 and occupancy_percent<=59:
    print("Moderate Demand")
  else:
    print("Low Demand")
# Out:
# Enter Nof of seat :2
# Enter Show name: eee
# Enter Total seat: 400
# Enter Booked seat: 200
# eee 400 200 50.0
# Occupancy Percent: 50.0 %
# Moderate Demand
# Enter Show name: eee
# Enter Total seat: 400
# Enter Booked seat: 200
# eee 400 200 50.0
# Occupancy Percent: 50.0 %
# Moderate Demand
